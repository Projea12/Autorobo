# %% [markdown]
# # 01 — Environment Sanity Check
#
# **Purpose:** Verify the MuJoCo simulation environment is set up correctly before training.
#
# ## What this notebook checks:
# 1. MuJoCo and gymnasium imports work
# 2. The `MobileManipulationEnv-v0` can be instantiated
# 3. Observation and action spaces have the expected shapes
# 4. A random rollout completes without errors
# 5. Rendering produces valid RGB frames
# 6. Reset randomisation produces varied initial states
#
# ## When to run:
# - After first-time environment setup (`scripts/setup_env.sh`)
# - After modifying the MuJoCo scene XML
# - After updating `interfaces/mujoco_interface.py`
# - Before starting Phase 3 navigation training
#
# ## Expected outcome:
# All cells run without error. Final cell displays a rendered frame from the environment.

# %%
# TODO: Phase 3 — implement environment sanity check cells
# import mujoco
# import gymnasium as gym
# from interfaces.mujoco_interface import MuJoCoInterface
# print(f'MuJoCo version: {mujoco.__version__}')
# print(f'Gymnasium version: {gym.__version__}')
raise NotImplementedError('TODO: Phase 3 — implement env sanity check')

# %% [markdown]
# # 03 — Perception Stack Debug
#
# **Purpose:** Interactively debug and visualise the full perception pipeline:
# YOLOv8 detection → SAM2 segmentation → DepthAnything depth estimation → grasp pose.
#
# ## What this notebook covers:
# 1. Load test images from the MuJoCo simulator (rendered RGB + depth)
# 2. Run YOLOv8 object detection and visualise bounding boxes with confidence scores
# 3. Run SAM2 segmentation prompted by YOLO bounding boxes — visualise masks
# 4. Run DepthAnything v2 — visualise colourised depth map
# 5. Fuse detection + mask + depth to estimate object 3D centroid
# 6. Visualise grasp pose candidates from GraspEstimator
# 7. Compare perception output vs ground-truth MuJoCo object poses (error analysis)
#
# ## When to run:
# - During Phase 6 (perception integration) to validate each model
# - When object detection accuracy drops in training
# - When debugging grasp failures caused by pose estimation error
# - After fine-tuning YOLOv8 on YCB-Video dataset
#
# ## Inputs:
# - Test images from `data/perception_test/`
# - Model checkpoints in `models/perception/`
#
# ## Expected outcome:
# - YOLO detection mAP > 0.7 on tabletop objects
# - Depth estimation error < 5cm at 0.5m range
# - Grasp pose error < 2cm translation, < 15° rotation

# %%
# TODO: Phase 6 — implement perception debug cells
# from perception.detector import ObjectDetector
# from perception.segmenter import ObjectSegmenter
# from perception.depth import DepthEstimator
# from perception.grasp_estimator import GraspEstimator
# import cv2
# import matplotlib.pyplot as plt
raise NotImplementedError('TODO: Phase 6 — implement perception pipeline debug notebook')
